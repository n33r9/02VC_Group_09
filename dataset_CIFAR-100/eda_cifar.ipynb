# %%
# intall lib
# !pip install pandas numpy matplotlib seaborn scikit-learn joblib opencv-python-headless tqdm

# %%
# ============================
# CIFAR EDA – FULL NOTEBOOK
# ============================

import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from collections import Counter

# ----------------------------
# 1. Load CIFAR100 (or CIFAR10)
# ----------------------------

transform = transforms.Compose([
    transforms.ToTensor(),
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True,
                                         download=True, transform=transform)
testset = torchvision.datasets.CIFAR100(root='./data', train=False,
                                        download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=64,
                                          shuffle=True, num_workers=2)

classes = trainset.classes
num_classes = len(classes)

print("Number of training samples:", len(trainset))
print("Number of test samples:", len(testset))
print("Number of classes:", num_classes)
print("Example classes:", classes[:10])
